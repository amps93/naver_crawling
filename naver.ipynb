# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = 'https://news.naver.com/main/list.naver?mode=LS2D&sid2=731&sid1=105&mid=shm&date=20230225&page=1'
header = {"user-agent": "Mozilla/5.0"}

html = requests.get(url, headers=header)
soup = BeautifulSoup(html.text, 'html.parser')
          
print(soup.title)
# Out:
# <title>IT/과학 홈 : 네이버 뉴스	</title>

# %%
link_li = []

for i in range(1,11):
    link_li.append(soup.select('#main_content > div.list_body.newsflash_body > ul.type06_headline > li:nth-of-type(' + str(i) + ') > dl > dt > a')[0].attrs['href'])
    
for i in range(1, 11):
    link_li.append(soup.select('#main_content > div.list_body.newsflash_body > ul.type06 > li:nth-of-type(' + str(i) + ') > dl > dt > a')[0].attrs['href'])

# %%
link_li
# Out:
# ['https://n.news.naver.com/mnews/article/001/0013779027?sid=105',
#  'https://n.news.naver.com/mnews/article/001/0013778881?sid=105',
#  'https://n.news.naver.com/mnews/article/001/0013778864?sid=105',
#  'https://n.news.naver.com/mnews/article/003/0011710901?sid=105',
#  'https://n.news.naver.com/mnews/article/003/0011710900?sid=105',
#  'https://n.news.naver.com/mnews/article/003/0011710899?sid=105',
#  'https://n.news.naver.com/mnews/article/003/0011710898?sid=105',
#  'https://n.news.naver.com/mnews/article/003/0011710897?sid=105',
#  'https://n.news.naver.com/mnews/article/003/0011710896?sid=105',
#  'https://n.news.naver.com/mnews/article/003/0011710895?sid=105',
#  'https://n.news.naver.com/mnews/article/003/0011710894?sid=105',
#  'https://n.news.naver.com/mnews/article/003/0011710893?sid=105',
#  'https://n.news.naver.com/mnews/article/003/0011710872?sid=105',
#  'https://n.news.naver.com/mnews/article/648/0000014165?sid=105',
#  'https://n.news.naver.com/mnews/article/092/0002283770?sid=105',
#  'https://n.news.naver.com/mnews/article/001/0013778756?sid=105',
#  'https://n.news.naver.com/mnews/article/003/0011710774?sid=105',
#  'https://n.news.naver.com/mnews/article/001/0013778627?sid=105',
#  'https://n.news.naver.com/mnews/article/001/0013778626?sid=105',
#  'https://n.news.naver.com/mnews/article/001/0013778625?sid=105']

# %%
title_lst = []
description_lst = []
date_lst = []

for link in link_li:
    header = {"user-agent": "Mozilla/5.0"}

    html = requests.get(link, headers=header)
    soup = BeautifulSoup(html.text, 'html.parser')
    

    title = soup.find('h2', {'id': 'title_area'})
    title_lst.append(title.text)


    description = soup.find('div', {'id': 'dic_area'})
    description = description.text
    description_lst.append(description)

    date = soup.find('span', {'class': 'media_end_head_info_datestamp_time _ARTICLE_DATE_TIME'})
    date = date['data-date-time']
    date_lst.append(date)
    
df = pd.DataFrame(zip(date_lst, title_lst, description_lst), columns=['date', 'title', 'description'])

# %%
# Out:
#                    date                                           title  \
# 0   2023-02-25 17:15:11              "사지 마세요" 냉정한 틱톡 리뷰…이젠 '디인플루언서'가 뜬다
# 1   2023-02-25 14:31:56            [MWC] 망 이용대가 글로벌 논란 재점화…EU·넷플릭스 기조연설
# 2   2023-02-25 13:19:12           [MWC] CES 혁신상 스타트업, 유럽서 투자 유치…4YFN 참가
# 3   2023-02-25 11:53:17                           KT, 모바일 월드 콩그레스 부스 설치
# 4   2023-02-25 11:53:17                              KT, MWC 2023 부스 설치
# 5   2023-02-25 11:53:17                              KT, MWC 2023 부스 설치
# 6   2023-02-25 11:53:17                           KT, 모바일 월드 콩그레스 부스 설치
# 7   2023-02-25 11:53:17                           KT, 모바일 월드 콩그레스 부스 설치
# 8   2023-02-25 11:53:17                              KT, MWC 2023 부스 설치
# 9   2023-02-25 11:53:17                              KT, MWC 2023 부스 설치
# 10  2023-02-25 11:53:17                           KT, 모바일 월드 콩그레스 부스 설치
# 11  2023-02-25 11:53:17                              KT, MWC 2023 부스 설치
# 12  2023-02-25 11:00:00          [MWC23 ③] 韓 쏘아올린 '망대가' 글로벌 공론화…격론 펼쳐진다
# 13  2023-02-25 10:16:01            [보니하니]갤S23 울트라, 관악산 정상서 서울랜드 상징 '또렷'
# 14  2023-02-25 10:05:01                   "애플, MR헤드셋 소프트웨어 결함…생산차질 불가피"
# 15  2023-02-25 10:00:03   [위클리 스마트] 디자인·화면에 '어텐션'…'뉴진스 랩톱' LG그램 스타일 써보니
# 16  2023-02-25 09:00:00  [MWC23 ②] 챗GPT? 한국형 AI로 승부수…SKT·KT 글로벌 기술력 뽐낸다
# 17  2023-02-25 08:13:54                                  MWC 부스 설치하는 KT
# 18  2023-02-25 08:13:53                                  MWC 부스 설치하는 KT
# 19  2023-02-25 08:13:51                           KT, 모바일 월드 콩그레스 부스 설치
#
#                                           description
# 0   \nWP "과소비 조장하는 광고영상 대신 솔직한 정보 신뢰"\n\n\n\n"비싼 것...
# 1   \nEU '기가비트 연결법' 앞두고 의견 수렴…넷플릭스 CEO 발언 주목\n\n\n...
# 2   \n\n\n\n\nMWC 스타트업 전시회 '4YFN(4 Years From Now)...
# 3   \n\n\n\n\n[바르셀로나(스페인)=뉴시스] 사진공동취재단 = 24일(현지시간)...
# 4   \n\n\n\n\n[바르셀로나(스페인)=뉴시스] 사진공동취재단 = 24일(현지시간)...
# 5   \n\n\n\n\n[바르셀로나(스페인)=뉴시스] 사진공동취재단 = 24일(현지시간)...
# 6   \n\n\n\n\n[바르셀로나(스페인)=뉴시스] 사진공동취재단 = 24일(현지시간)...
# 7   \n\n\n\n\n[바르셀로나(스페인)=뉴시스] 사진공동취재단 = 24일(현지시간)...
# 8   \n\n\n\n\n[바르셀로나(스페인)=뉴시스] 사진공동취재단 = 24일(현지시간)...
# 9   \n\n\n\n\n[바르셀로나(스페인)=뉴시스] 사진공동취재단 = 24일(현지시간)...
# 10  \n\n\n\n\n[바르셀로나(스페인)=뉴시스] 사진공동취재단 = 24일(현지시간)...
# 11  \n\n\n\n\n[바르셀로나(스페인)=뉴시스] 사진공동취재단 = 24일(현지시간)...
# 12  \n기사내용 요약첫째날 키노트 이어 둘째날 세션에서도 연속 논의'망대가'法 반대 넷...
# 13  \n갤럭시S23 울트라와 함께한 겨울 관악산 등반정상서 과천 시내 한눈에…배터리도 ...
# 14  \n애플 전문가 궈밍치 전망…"올 생산량 50만대 수준 머물듯"애플의 혼합현실(MR...
# 15  \n인텔 13세대 프로세서로 빠지지 않는 성능…발열과 기기 연결성은 '옥에 티'\n...
# 16  \n기사내용 요약SKT, 핵심 전시장에 단독 부스 마련…초거대AI·AI반도체 소개유...
# 17  \n\n\n\n\n    (서울=연합뉴스) 24일(현지시간) 스페인 바르셀로나 피라...
# 18  \n\n\n\n\n    (서울=연합뉴스) 24일(현지시간) 스페인 바르셀로나 피라...
# 19  \n\n\n\n\n    (서울=연합뉴스) 24일(현지시간) 스페인 바르셀로나 피라...
